# %% [markdown]
# # Training a spiking network to deploy to the Xylo digital SNN

# %%
# -- Some useful imports

# - Time-series data
from rockpool import TSContinuous, TSEvent

# - Rich printing
try:
    from rich import print
except:
    pass

# - Numpy
import numpy as np

# - Import and configure matplotlib for plotting
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [12, 4]
plt.rcParams['figure.dpi'] = 300

# %% [markdown]
# ## Considerations

# %% [markdown]
# This notebook shows how to define a spiking model using the ``LIFTorch`` class and train it on a simple task. For simplicity, the used task is just to spike at certain times given random but fixed input.
#
# In this case we target the Xylo hardware and have to consider the hardware constraints. I.e. the hardware has to receive spiking input, has only 16 input channels and 1000 recurrently connected neurons.
#
# We will use Samna to create and validate a model definiton for Xylo and the use Cimulator to simulate it.
#
# **Samna and Cimulator are required for this tutorial**

# %% [markdown]
# ## Define a task

# %% [markdown]
# We will define a simple random regression task, where random frozen input noise is mapped to randomly chosen smooth output signals. We implement this using a ``Dataset``-compatible class, implementing the ``__len__()`` and ``__getitem__()`` methods.

# %%
import torch

# - Define a dataset class implementing the indexing interface
class MultiClassRandomSpikeTimeMapping:
    def __init__(self,
                 num_classes: int = 2,
                 sample_length: int = 100,
                 input_channels: int = 50,
                 target_channels: int = 2):
        # - Record task parameters
        self._num_classes = num_classes
        self._sample_length = sample_length
        
        # - Draw random input signals
        self._inputs = np.abs(np.random.randn(num_classes, sample_length, input_channels) + 1.)
        self._inputs = np.round(self._inputs / np.abs(self._inputs).max() * 5)
        self._inputs = np.clip(self._inputs, 0, 5)
                                         
        # - Generate target output signals
        time_base = np.atleast_2d(np.arange(sample_length) / sample_length).T
        self._targets = np.zeros((num_classes, sample_length, target_channels))
        for c in range(num_classes):
            for i in range(target_channels):
                self._targets[c, np.random.choice(np.arange(self._targets[c, :, i].size-10)+10, 1), i] = 1
    
    def __len__(self):
        # - Return the total size of this dataset
        return self._num_classes
    
    def __getitem__(self, i):
        # - Return the indexed dataset sample
        return torch.Tensor(self._inputs[i]), torch.Tensor(self._targets[i])

# %%
# - Instantiate a dataset
Nin = 16
Nout = 2
num_classes = 2
T = 50
dt = 1e-3
ds = MultiClassRandomSpikeTimeMapping(num_classes = num_classes,
                                      input_channels = Nin,
                                      target_channels = Nout,
                                      sample_length = T,
                                      )

# Display the dataset classes
plt.figure()
for i, sample in enumerate(ds):
    plt.subplot(2, len(ds), i + 1)
    plt.imshow(sample[0].T, aspect='auto', interpolation='None')
    plt.title(f'Input class {i}')
    
    plt.subplot(2, len(ds), i + len(ds) + 1)
    TSEvent.from_raster(sample[1], dt = dt).plot()
    plt.xlabel(f'Target class {i}')

# %% [markdown]
# ## Define a network

# %% [markdown]
# We'll define a very simple MLP-like network to solve the spike timing task. We define 3 layers, input, hidden and output of which all are spiking. To demonstrate the aliasing capabilities of Xylo we also include a residual block over the hidden layers. We'll use the rockpool torch modules

# %%
from torch.nn import Linear, Tanh
from rockpool.nn.modules import LIFTorch
from rockpool.nn.modules import TorchModule, LinearTorch
from rockpool.nn.modules import LowPass
# from rockpool.nn.layers import FFUpDown
from rockpool.nn.combinators import Sequential, Residual
from rockpool import TSContinuous
import copy

Nhidden = 63

net = Sequential(
    LinearTorch((Nin, Nhidden), has_bias = False),
    LIFTorch((Nhidden), tau_mem = 0.002, tau_syn = 0.002, dt = dt, device = 'cpu'),

    Residual(
        LinearTorch((Nhidden, Nhidden), has_bias = False),
        LIFTorch((Nhidden), tau_mem = 0.002, tau_syn = 0.002, dt = dt, device = 'cpu'),
    ),

    LinearTorch((Nhidden, Nout), has_bias = False),
    LIFTorch((Nout), tau_mem = 0.002, tau_syn = 0.002, dt = dt, device = 'cpu'),
)
net
# Out:
# WARNING    /Users/dylan/SynSense Dropbox/Dylan Muir/LiveSync/Development/rockpool_GIT/rockpool/nn/modules/__init__.py:48: UserWarning: NEST modules not available: 'NEST' backend not found. Modules that rely on NEST will not be available.
#   warnings.warn(f"NEST modules not available: {err}")
#  [py.warnings]
# Could not import package: No module named 'iaf_nest'
# TorchSequential  with shape (16, 2) {
#     LinearTorch '0_LinearTorch' with shape (16, 63)
#     LIFTorch '1_LIFTorch' with shape (63,)
#     TorchResidual '2_TorchResidual' with shape (63, 63) {
#         LinearTorch '0_LinearTorch' with shape (63, 63)
#         LIFTorch '1_LIFTorch' with shape (63,)
#     }
#     LinearTorch '3_LinearTorch' with shape (63, 2)
#     LIFTorch '4_LIFTorch' with shape (2,)
# }

# %%
class SimpleNet(TorchModule):
    def __init__(self,
                 Nin: int,
                 Nhidden: int,
                 Nout: int,
                 dt: float,
                 *args, **kwargs,
                ):
        super().__init__(shape = (Nin, Nhidden, Nout), *args, **kwargs)
        
        self.Nin = Nin
        self.Nhidden = Nhidden
        self.Nout = Nout
        
        self.threshold = 1.0
        self.learning_window = 0.3

        self.lin_in = Linear(Nin, Nhidden, bias = False)
        self.spk_in = LIFLayer(n_neurons=Nhidden,
                            n_synapses=1,
                            batch_size=1,
                            tau_mem=0.002,
                            tau_syn=0.002,
                            threshold=self.threshold,
                            learning_window=self.learning_window,
                            dt=dt,
                            device='cpu')
        
        self.lin_hid = Linear(Nhidden, Nhidden, bias = False)
        self.spk_hid = LIFLayer(n_neurons=Nhidden,
                            n_synapses=1,
                            batch_size=1,
                            tau_mem=0.002,
                            tau_syn=0.002,
                            threshold=self.threshold,
                            learning_window=self.learning_window,
                            dt=dt,
                            device='cpu')
        
        self.lin_out = Linear(Nhidden, Nout, bias = False)
        self.spk_out = LIFLayer(n_neurons=Nout,
                            n_synapses=1,
                            batch_size=1,
                            tau_mem=0.002,
                            tau_syn=0.002,
                            threshold=self.threshold,
                            learning_window=self.learning_window,
                            dt=dt,
                            device='cpu')
        
        self._record_dict = {}
        
        
    def forward(self, inp):
        out = self.lin_in(inp)
        out, _, self._record_dict['spk_in'] = self.spk_in(out.unsqueeze(1).unsqueeze(1), record=True)
        self._record_dict['rec_spk_inp'] = out.clone()
        skip = out.clone()
        
        out = self.lin_hid(out.squeeze(1).float())
        out, _, self._record_dict['rec_hid'] = self.spk_hid(out.unsqueeze(1).unsqueeze(1), record=True)
        
        # skip connection
        out = out + skip
        
        self._record_dict['rec_spk_hid'] = out.clone()
        
        out = self.lin_out(out.squeeze(1).float())
        out, _, self._record_dict['rec_out'] = self.spk_out(out.unsqueeze(1).unsqueeze(1), record=True)
        self._record_dict['rec_spk_out'] = out.clone()
        
        return out.squeeze(1)
    
    def evolve(self, input, record: bool = False, *args, **kwargs):
        out, new_states, _ = super().evolve(input, record, *args, **kwargs)
        
        rec_dict = self._record_dict if record else {}

        return out, new_states, rec_dict
    
    def torch_params(self):
        return torch.nn.Module.parameters(self)
    
    def detach(self):
        self.spk_in.detach()
        self.spk_hid.detach()
        self.spk_out.detach()
        self.spk_in.vmem *= 0
        self.spk_in.isyn *= 0
        self.spk_hid.vmem *= 0
        self.spk_hid.isyn *= 0
        self.spk_out.vmem *= 0
        self.spk_out.isyn *= 0
    
    def to_weight_matrix(self):

        w_inp = torch.zeros(self.Nin, self.Nhidden, 2)
        w_inp[:, :Nhidden, 0] = self.lin_in.weight.data.T
        
        w_rec = torch.zeros(self.Nhidden*2, self.Nhidden*2, 2)
        w_rec[:Nhidden, Nhidden:, 0] = self.lin_hid.weight.data.T
        
        w_out = torch.zeros(self.Nhidden*2, self.Nout)
        w_out[Nhidden:, :] = self.lin_out.weight.data.T
        
        aliases = []
        for n in range(len(w_rec)):
            if n < Nhidden:
                aliases.append([n + Nhidden]) # skip connection skipping the hidden layer
            else:
                aliases.append([])
        
        return w_inp.detach().cpu().numpy(), w_rec.detach().cpu().numpy(), w_out.detach().cpu().numpy(), aliases
    
    def to_vmem_dash(self):
        dash_mems = []
        dash_mems += self.spk_in.alpha_mem.int().cpu().numpy().tolist() * self.Nhidden
        dash_mems += self.spk_hid.alpha_mem.int().cpu().numpy().tolist() * self.Nhidden
        
        dash_mems_out = self.spk_out.alpha_mem.int().cpu().numpy().tolist() * self.Nout
        
        return np.array(dash_mems), np.array(dash_mems_out)
    
    def to_syn_dash(self):
        dash_syns = []
        dash_syns += self.spk_in.alpha_syn.int().cpu().numpy().tolist() * self.Nhidden
        dash_syns += self.spk_hid.alpha_syn.int().cpu().numpy().tolist() * self.Nhidden
        
        dash_syns_out = self.spk_out.alpha_syn.int().cpu().numpy().tolist() * self.Nout
        dash_syns = np.atleast_2d(dash_syns).T.tolist()
        
        return np.array(dash_syns), np.array(dash_syns_out)

# %%
# Nhidden = 63

# net = SimpleNet(Nin, Nhidden, Nout, dt)

# %% [markdown]
# ## Training loop

# %% [markdown]
# As usually done for a regression task, we are using the MSE loss and Adam during training.
# Everything works exactly the same as for the non-spiking layers with the exception that we are resetting the state of the neurons after each sameple using the `detach` function.

# %%
# - Useful imports
from tqdm.autonotebook import tqdm
from torch.optim import Adam, SGD
from torch.nn import MSELoss

# net = SimpleNet(Nin, Nhidden, Nout, dt)

# - Get the optimiser functions
optimizer = Adam(net.parameters().astorch(), lr=1e-4)

# - Loss function
loss_fun = MSELoss()

# - Record the loss values over training iterations
loss_t = []

num_epochs = 1000
iterator = tqdm(range(num_epochs))
# - Loop over iterations
for _ in iterator:
    epoch_loss = 0
    for input, target in ds:
        for p in net.parameters().astorch():
            if hasattr(p, 'detach'):
                p.detach()
#         net.detach()
        optimizer.zero_grad()
                
        output, _, record = net(input.unsqueeze(0), record = True)
              
        loss = loss_fun(output, target.unsqueeze(0))
        loss += 100 * torch.sum(record['4_LIFTorch']['vmem'] ** 2)
        loss += 100 * (2 - torch.sum(record['4_LIFTorch_output'])) ** 2

        if loss.item() > 0:
            loss.backward()
            optimizer.step()
        
        epoch_loss += loss.item()
        
    # - Keep track of the loss
    loss_t.append(epoch_loss)
    if epoch_loss == 0:
        iterator.close()
        break
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]

# %% [markdown]
# After training, we inspect the loss and plot the result of the training. The loss is very noisy but is getting to 0 after a while. Also the output spikes matches the target, if that's not the case, please retrain.

# %%
# - Plot the loss over iterations
plt.plot(loss_t)
plt.yscale('log')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.title('Training loss');

# %%
# - Evaluate classes
for i_class, [input, target] in enumerate(ds):
    
    # - Evaluate network
    net = net.reset_state()
    
    output, _, rec_float = net(input.unsqueeze(0), record = True)
    
    # - Plot output and target
    plt.figure()
    plt.plot(output.detach().cpu().squeeze().numpy(), 'k-')
    plt.plot(target, '--')
    plt.xlabel('Time (steps)')
    plt.ylabel('Value')
    plt.legend(['Output $y_0$',
                'Output $y_1$',
                'Target $\hat{y}_0$',
                'Target $\hat{y}_1$',
               ])
    plt.title(f'Class {i_class}')

# %%
rec_float['4_LIFTorch']['vmem']
# Out:
# tensor([[[ -1.0339,  -1.2978],
#          [ -1.2287,  -1.8463],
#          [ -1.9100,  -2.4864],
#          [ -2.4604,  -3.2014],
#          [ -3.2220,  -3.8907],
#          [ -3.6852,  -4.3599],
#          [ -4.3494,  -5.3022],
#          [ -4.8578,  -5.8501],
#          [ -5.2320,  -6.5013],
#          [ -5.2292,  -7.2333],
#          [ -5.0963,  -8.0258],
#          [ -5.4593,  -8.7253],
#          [ -5.6533,  -9.4596],
#          [ -6.1693,  -9.9541],
#          [ -6.4508, -10.5087],
#          [ -6.6984, -10.9830],
#          [ -6.3314, -11.0936],
#          [ -6.3888, -10.9854],
#          [ -6.2888, -10.9422],
#          [ -6.3177, -10.9597],
#          [ -6.2362, -10.6294],
#          [ -5.9707, -10.1561],
#          [ -5.5399,  -9.6410],
#          [ -5.3007,  -9.4428],
#          [ -5.1659,  -9.1008],
#          [ -5.0304,  -8.9216],
#          [ -4.8381,  -9.1367],
#          [ -5.2811,  -9.5665],
#          [ -5.4537,  -9.7114],
#          [ -5.4753,  -9.7488],
#          [ -5.6741,  -9.7040],
#          [ -5.7621,  -9.6525],
#          [ -6.0769,  -9.2827],
#          [ -6.2854,  -8.8103],
#          [ -6.2901,  -8.8273],
#          [ -6.0068,  -8.8835],
#          [ -6.0951,  -9.0467],
#          [ -6.3632,  -9.2233],
#          [ -6.5741,  -9.3280],
#          [ -6.5625,  -9.3479],
#          [ -6.6271,  -9.2701],
#          [ -6.5293,  -9.4407],
#          [ -6.4385,  -9.6325],
#          [ -6.3528,  -9.7982],
#          [ -6.6557,  -9.8671],
#          [ -6.4353,  -9.8674],
#          [ -6.1230, -10.0597],
#          [ -6.1822,  -9.9253],
#          [ -6.2995,  -9.9512],
#          [ -6.5070,  -9.8764]]])

# %% [markdown]
# ## Deploying this network to Xylo / Cimulator
#
# Now that the network learned this simple task, we can try to run it in a simulation of Xylo.
# Remember, Xylo has some limitations:
# - Neurons
#     - 16 input channels
#     - 1000 recurrently connected neurons
#     - 8 output channels
#
# - Connectivity
#     - Fanout between input and recurrent layer is unlimited
#     - Fanout between recurrent neurons is maximally 63
#     - Fanout between recurrent and output neurons is unlimited
#     - Aliases (skip connections) only in direction of increasing neuron id
#
# - Neuron model
#     - Quantized Leaky Integrate and Fire
#     - 16 bit membrane potential
#     - 16 bit synaptic current
#     - 8 bit weights
#     - 4 bit bitshift decay for membrane and synapses
#     - special: possibly 2 synapses per neuron
#
# - Simulation
#     - Integration method:
#         - Forward euler, resolution between 1 ms and 10 ms
#
#
# For details, please take a look at the XyloSpecs and the documentation of Samna.
#
# In order to run our model on Xylo, we have to fulfill those requirements. The SNN in this example already fulfills the connectivtiy and neuron requirements. Moreover, the Torch-based LIFLayer in rockpool already simulates the bitshift decay (which is one of the reasons why it is so slow). So the main difficulty is to bring the parameters to the correct format and also to quantize the weights and thresholds to 8 resp. 16 bit.
#
# So let's first look at the `to_weight_matrix` and the `to_syn/mem_taus` functions.

# %%
w_inp_float, w_rec_float, w_out_float, aliases = net.to_weight_matrix()

fig = plt.figure(figsize=(16, 3))
ax = fig.add_subplot(141)
ax.set_title("w_inp float")
im = ax.imshow(w_inp_float[:, :, 0], aspect='auto', interpolation='None')
plt.colorbar(im)

ax = fig.add_subplot(142)
ax.set_title("w_rec float")
im = ax.imshow(w_rec_float[:, :, 0], aspect='auto', interpolation='None')
plt.colorbar(im)

ax = fig.add_subplot(143)
ax.set_title("aliases")
aliases_ = np.zeros_like(w_rec_float[:, :, 0])
for i, a in enumerate(aliases):
    if len(a) > 0:
        aliases_[i, a[0]] = 1
im = ax.imshow(aliases_, aspect='auto', interpolation='None')

ax = fig.add_subplot(144)
ax.set_title("w_out float")
im = ax.imshow(w_out_float, aspect='auto', interpolation='None')
plt.colorbar(im);
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-87090d874488> in <module>
# ----> 1 w_inp_float, w_rec_float, w_out_float, aliases = net.to_weight_matrix()
#       2
#       3 fig = plt.figure(figsize=(16, 3))
#       4 ax = fig.add_subplot(141)
#       5 ax.set_title("w_inp float")
#
# /Users/Shared/anaconda3/envs/py36_rp/lib/python3.6/site-packages/torch/nn/modules/module.py in __getattr__(self, name)
#    1129                 return modules[name]
#    1130         raise AttributeError("'{}' object has no attribute '{}'".format(
# -> 1131             type(self).__name__, name))
#    1132
#    1133     def __setattr__(self, name: str, value: Union[Tensor, 'Module']) -> None:
#
# AttributeError: 'TorchSequential' object has no attribute 'to_weight_matrix'

# %% [markdown]
# As can be seen, the input weight matrix has a dimension of (16, 63) and contains the weights of the first linear layer of the model.
#
# The recurrent weight matrix is nonzero in the top-right quarter, reflecting that the first 63 neurons connect to the next 63 neurons (filled with the weights on the second linear layer of the model). Note that there are no recurrent connections as the diagonal blocks are all zero.
#
# In the model we defined a skip connection skipping the hidden layer. In Torch that's easily done by the + operator, adding the activations of one layer to another and hence skipping the layers in between (the dimensions must be compatible). We get the same behavior in Xylo using aliases. If neuron 'a' has alias 'b' means that the spike count of 'b' is increased by the spike count of 'a'. In our case, we aliased the input neurons to the hidden neurons to add up their activations.
#
# The output weight matrix connects the second population to the output, hence there are non-zero values for the last 63 neurons to the two output neurons.
#
# The time-constants for the exponential decay are less exciting; they are all 2 ms. But this timeconstant has to be translated to values for bit-shift decay (dash). The equation for that is:
#
# $dash = [\log_2(\tau / dt)]$
#
# Hence, a timeconstant of 2ms with a simulation resolution of 1 ms is 1.
#
# But what is done with this bitshift of 1? Let's have an example and compare exponential decay to bitshift decay.

# %%
tau = 20e-3 # 20 ms
dt_ = 1e-3 # 1 ms resolution

dash = np.round(np.log2(tau / dt_)).astype(int)
exp_propagator = np.exp(-dt_ / tau)

simtime = 0.2 # 1 sec
t_ = 0
v_tau = [1000]
v_dash = [1000]
while t_ < simtime:
    v_tau.append(v_tau[-1] * exp_propagator)
    if (v_dash[-1] >> dash) > 0:
        v_dash.append(v_dash[-1] - (v_dash[-1] >> dash))
    else:
        v_dash.append(int(np.clip(v_dash[-1] - 1, 0, np.inf)))
    t_ += dt_
    
plt.plot(np.arange(0, len(v_tau)) * dt_, v_tau, label='exponential decay')
plt.plot(np.arange(0, len(v_dash)) * dt_, v_dash, label='bitshift decay')
plt.legend()
plt.xlabel("Time (s)");

# %% [markdown]
# As clearly visible, the bitshift decay behaves similar to an exponential decay but poses limitations on time-constants and resolution. Even worse, SNNs are very sensitive on the time-constants and hence even those 'small' differences can change the dynamics in the network drastically.
# BUT bitshifts are extremely cheap to compute and put into hardware which is the main reason we are using them on Xylo.
#
# Now, let's investigate the quantization of weights. We use the following function:

# %%
def quantize(model, 
             weight_shift: int = 0, 
             weight_shift_out: int = 0,
             save_filename: str = None,
             dt = 0.001
             ):

    w_in, w_rec, w_out, aliases = model.to_weight_matrix()
    dash_mem, dash_mem_out = model.to_vmem_dash()
    dash_syn, dash_syn_out = model.to_syn_dash()
    dash_syn_2 = dash_syn
    
    # get threshold relative to reset potential
    v_th_rel = model.threshold 
    
    max_val = 0
    max_val = np.max([max_val, np.max(np.abs(w_in))])
    max_val = np.max([max_val, np.max(np.abs(w_rec))])
    
    max_val_out = np.max([0, np.max(np.abs(w_out))])
    
    # determine scaling value
    max_quant_val = 2 ** (8 - 1) - 1
    scaling = max_quant_val / max_val
    scaling_out = max_quant_val / max_val_out
    
    # scale weights
    weights_in = np.round(w_in * scaling).astype(int)
    weights_rec = np.round(w_rec * scaling).astype(int)
    weights_out = np.round(w_out * scaling_out).astype(int)
    
    # thresholds
    threshold = np.repeat(np.round(v_th_rel * scaling).astype(int) << weight_shift, len(w_rec)) 
    threshold_out = np.repeat(np.round(v_th_rel * scaling_out).astype(int) << weight_shift_out, len(w_out.T)) 

    return {"weights_in": weights_in,
            "weights_rec": weights_rec,
            "weights_out": weights_out,
            "aliases": aliases,
            "threshold": threshold,
            "threshold_out": threshold_out,
            "weight_shift_rec": weight_shift,
            "weight_shift_out": weight_shift_out,
            "dash_mem": dash_mem,
            "dash_mem_out": dash_mem_out,
            "dash_syn": dash_syn,
            "dash_syn_2": dash_syn_2,
            "dash_syn_out": dash_syn_out,}

# %%
quant_model_dict = quantize(net, weight_shift=0, weight_shift_out=0)

# %% [markdown]
# Now. let's visualize the quantized weight in comparison to the floating point weights.

# %%
fig = plt.figure(figsize=(16, 10))
ax = fig.add_subplot(321)
ax.set_title("w_inp float")
ax.hist(np.ravel(w_inp_float[w_inp_float != 0]), bins=2**8)

ax = fig.add_subplot(322)
ax.set_title("w_inp quant")
ax.hist(np.ravel(quant_model_dict['weights_in'][quant_model_dict['weights_in'] != 0]), bins=2**8)

ax = fig.add_subplot(323)
ax.set_title("w_rec float")
ax.hist(np.ravel(w_rec_float[w_rec_float != 0]), bins=2**8)

ax = fig.add_subplot(324)
ax.set_title("w_rec quant")
ax.hist(np.ravel(quant_model_dict['weights_rec'][quant_model_dict['weights_rec'] != 0]), bins=2**8)

ax = fig.add_subplot(325)
ax.set_title("w_out float")
ax.hist(np.ravel(w_out_float[w_out_float != 0]), bins=2**8)

ax = fig.add_subplot(326)
ax.set_title("w_out quant")
ax.hist(np.ravel(quant_model_dict['weights_out'][quant_model_dict['weights_out'] != 0]), bins=2**8);

# %% [markdown]
# As you can see, the floating point weights all below 0 while the quantized weights got scaled to be between -128 and +127. In this case, we are lucky and the distribution of weights look very similar.
# Unlucky cases would be:
# - Weight distribution is not centered around 0
# - A few very strong weights
# - Non-flat distribution
#
# In all those 'unlucky' cases, the quantized weights could not make use of the complete range and might the resulting network behavior might be very different compared with the floating point network. There might be 'tricks' to avoid those situations.
#
# In this case, though, everything looks fine. So let's go to the next step and create a xylo configuration and simulate that network.

# %%
from rockpool.devices.xylo import config_from_specification
xylo_conf, is_valid, message = config_from_specification(**quant_model_dict)
print('Valid config: ', is_valid)

# %%
from rockpool.devices.xylo import XyloCim
from rockpool.timeseries import TSEvent

# %%
cim = XyloCim.from_config(xylo_conf, dt=dt).timed(add_events = True)

# %%
# - Evaluate classes
for i_class, [input, target] in enumerate(ds):
    
    cim.reset_state()
    cim.reset_time()
    inp = TSEvent.from_raster(input.cpu().numpy(), dt=dt, t_start=0)
    output, _, rec_cim = cim(inp, record = True)

    # - Plot output and target
    plt.figure()
    output.plot()
    plt.plot(np.arange(len(target))*dt, target, '--')
    plt.xlabel('Time (s)')
    plt.ylabel('Value')

    plt.ylim([0, target.max()])
    plt.title(f'Class {i_class}')

# %% [markdown]
# As you can see, the quantized model still spikes at the same times as the floating point model (see figure after training). Let's briefly compare the internal dynamics.

# %%
rec_float.keys()

# %%
fig = plt.figure(figsize=(16, 16))

ax = fig.add_subplot(5, 2, 1)
plt.plot(rec_float['spk_in']['Isyn'].squeeze(1).squeeze(1).detach())
plt.plot(rec_float['rec_hid']['Isyn'].squeeze(1).squeeze(1).detach())
ax.set_title("Isyn inp / hidden float")

ax = fig.add_subplot(5, 2, 2)
rec_cim['Isyn'].plot()
ax.set_title("Isyn recurrent layer quant")

ax = fig.add_subplot(5, 2, 3)
plt.plot(rec_float['spk_in']['Vmem'].squeeze(1).squeeze(1).detach())
plt.plot(rec_float['rec_hid']['Vmem'].squeeze(1).squeeze(1).detach())
ax.set_title("Vmem inp / hidden float")

ax = fig.add_subplot(5, 2, 4)
rec_cim['Vmem'].plot()
ax.set_title("Vmem recurrent layer quant")

ax = fig.add_subplot(5, 2, 5)
spk_float = np.vstack([rec_float['rec_spk_inp'].squeeze(1).detach().T,
                       rec_float['rec_spk_hid'].squeeze(1).detach().T])
nids, times = np.where(spk_float)
plt.scatter(times, nids, s=1)
ax.set_title("spikes inp / hidden float")

ax = fig.add_subplot(5, 2, 6)
rec_cim['Spikes'].plot(s=1)
plt.scatter(times, nids, s=1)
ax.set_title("spikes recurrent layer quant")

ax = fig.add_subplot(5, 2, 7)
plt.plot(rec_float['rec_out']['Isyn'].squeeze(1).squeeze(1).detach())
ax.set_title("Isyn output float")

ax = fig.add_subplot(5, 2, 8)
rec_cim['Isyn_out'].plot()
ax.set_title("Isyn output quant")

ax = fig.add_subplot(5, 2, 9)
plt.plot(rec_float['rec_out']['Vmem'].squeeze(1).squeeze(1).detach())
ax.set_title("Vmem output float")

ax = fig.add_subplot(5, 2, 10)
rec_cim['Vmem_out'].plot()
ax.set_title("Vmem output quant");

# %% [markdown]
# Although it's probably hard to see as there are so many neurons, the dynamics within the networks look very similar.
